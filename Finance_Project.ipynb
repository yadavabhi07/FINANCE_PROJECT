# %% [markdown]
# ## Importing Library

# %%
# !pip install pandas_ta
# !pip install tabulate
# Out:
# Requirement already satisfied: pandas_ta in c:\program files\python311\lib\site-packages (0.3.14b0)
# Requirement already satisfied: pandas in c:\program files\python311\lib\site-packages (from pandas_ta) (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\program files\python311\lib\site-packages (from pandas->pandas_ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python311\lib\site-packages (from pandas->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python311\lib\site-packages\pytz-2023.3-py3.11.egg (from pandas->pandas_ta) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\program files\python311\lib\site-packages\tzdata-2023.3-py3.11.egg (from pandas->pandas_ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\program files\python311\lib\site-packages\six-1.16.0-py3.11.egg (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# WARNING: Skipping C:\Program Files\Python311\Lib\site-packages\torch-2.1.1.dist-info due to invalid metadata entry 'name'
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\blinker-1.6.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\click-8.1.7-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\colorama-0.4.6-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\contourpy-1.1.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\cycler-0.11.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\diamondpriceprediction-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\flask-2.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\fonttools-4.42.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\itsdangerous-2.1.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\jinja2-3.1.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\joblib-1.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\kiwisolver-1.4.4-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\matplotlib-3.8.0rc1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\neural_style_transfer-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\pytz-2023.3-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\scikit_learn-1.3.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\scipy-1.11.2-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\threadpoolctl-3.2.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\tzdata-2023.3-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\werkzeug-2.3.7-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# WARNING: Skipping C:\Program Files\Python311\Lib\site-packages\torch-2.1.1.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tabulate in c:\program files\python311\lib\site-packages (0.9.0)
# WARNING: Skipping C:\Program Files\Python311\Lib\site-packages\torch-2.1.1.dist-info due to invalid metadata entry 'name'
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\blinker-1.6.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\click-8.1.7-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\colorama-0.4.6-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\contourpy-1.1.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\cycler-0.11.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\diamondpriceprediction-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\flask-2.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\fonttools-4.42.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\itsdangerous-2.1.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\jinja2-3.1.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\joblib-1.3.2-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\kiwisolver-1.4.4-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\matplotlib-3.8.0rc1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\neural_style_transfer-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\pytz-2023.3-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\scikit_learn-1.3.0-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\scipy-1.11.2-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\threadpoolctl-3.2.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\tzdata-2023.3-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\werkzeug-2.3.7-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# WARNING: Skipping C:\Program Files\Python311\Lib\site-packages\torch-2.1.1.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas_ta as ta
from tabulate import tabulate
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Declaring Functions

# %%
# Bollinger Band Function
def bbands(data,window,std):
    rollmean=data['Close'].rolling(window=window).mean()
    rollstd=data['Close'].rolling(window=window).std()
    upperband=rollmean+std*0.25*rollstd
    lowerband=rollmean-std*0.25*rollstd
    trend=rollmean
    data['UpperBand']=upperband
    data['LowerBand']=lowerband
    data['Trend']=trend
    return data

# %%
# Define a function to create and get the Relative  Strength Index (RSI)
def RSI(data,window):
    delta=data['Close'].diff(1) # By-default 1 differencing
    gain=delta.where(delta>0,0)
    loss=delta.where(delta<0,0)
    avg_gain=gain.rolling(window).mean()
    avg_loss=loss.rolling(window).mean()
    RS=avg_gain/avg_loss
    RSI=100-(100/(1+RS))
    data['RSI']=RSI
    data['OverBought']=70
    data['OverSold']=30
    return data

# %% [markdown]
# # Applying Strategy

# %%
# From Strategy we only creating Buying Signal i.e 2
def strategy(data):
    signal=[]
    for i in range(len(data)):
        if data['Close'][i]<data['LowerBand'][i] and data['RSI'][i]<data['OverSold'][i]:
            indication=2 # Buy Signal
            signal.append('Buy')
        else:
            indication=0 # No signal
            signal.append('Null')
    data['Signal']=signal
    return data

# %%
def average_true_range(data, window=14):
    high_low = data['High'] - data['Low']
    high_close = (data['High'] - data['Close']).abs()
    low_close = (data['Low'] - data['Close']).abs()
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = ranges.max(axis=1)
    data['ATR'] = true_range.rolling(window=window).mean()
    return data

# %% [markdown]
# # Marking Take Profit line and Stop Loss line

# %%
# take profit stop loss function for ATR function
def tpsl(data):
    data['Take Profit']=0
    data['Stop Loss']=0
    for i in range(len(data)):
        if data['Signal'][i] == 'Buy':
            data['Take Profit'][i] = 15.0 * data['ATR'][i]
            data['Stop Loss'][i] = 12.0* data['ATR'][i]
        else:
            data['Take Profit'][i] = np.nan
            data['Stop Loss'][i] = np.nan

    return data

# %%
def target(data):
    target = []

    for i in range(len(data)):
        if data.Signal[i] == 'Buy':
            buy_price = data.Close[i]
            hit_target = False  # This flag will indicate if TP or SL was hit

            for j in range(i + 1, len(data)):  # Starting from i+1 because we want to check the candles after the buy signal
                if buy_price + data['Take Profit'][i] <= data['Close'][j]:
                    target.append(buy_price + data['Take Profit'][i])
                    hit_target = True
                    break
                elif buy_price - data['Stop Loss'][i] >= data['Close'][j]:
                    target.append(buy_price - data['Stop Loss'][i])
                    hit_target = True
                    break

            # If we reached the end of the dataset without hitting TP or SL
            if not hit_target:
                target.append(np.nan)
        else:
            target.append(np.nan)

    data['Target']=target
    return data

# %% [markdown]
# ## Calling Function

# %%
def best_param_bris(df):
    best_pnl = float('-inf')
    best_moving_avg = None
    best_rsi_moving_avg = None
    best_std = None

    for i in range(15, 30):
        for j in range(2, 15):
            for k in range(10, 25):
                data = df.copy()  # Create a copy of the original data
                data = bbands(data, i, j)
                data = RSI(data, k)
                data = average_true_range(data)
                data.dropna(inplace=True)
                data = strategy(data)
                data = tpsl(data)
                data = target(data)

                df_buy = data[data['Signal'] == 'Buy']  # Filter data for 'Buy' signals
                if not df_buy.empty:
                    df_buy['PNL'] = data['Target'] - data['Close']
                    pnl = df_buy['PNL'].sum()
                    # if pnl > best_pnl:
                    best_pnl = pnl
                    best_moving_avg = i
                    best_std = j
                    best_rsi_moving_avg = k

                    best_params = {
                        'Best PNL': best_pnl,
                        'Best Moving Average BBand': best_moving_avg,
                        'Best Moving Average RSI': best_rsi_moving_avg,
                        'Best STD BBand': best_std
                    }

                    print(best_params)
    # return best_params

# %%
best_param_bris(data)
# Out:
# {'Best PNL': -2551.6044205461253, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 2}
# {'Best PNL': -2224.626257331032, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 2}
# {'Best PNL': -2514.4755910805316, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 2}
# {'Best PNL': -2361.943299273081, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 2}
# {'Best PNL': -2737.769943543842, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 2}
# {'Best PNL': -2389.7710704599112, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 2}
# {'Best PNL': -2568.545708417894, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 2}
# {'Best PNL': -2634.0894341060102, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 2}
# {'Best PNL': -2838.0467042037426, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 2}
# {'Best PNL': -2803.9623879296455, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 2}
# {'Best PNL': -2766.2192430496225, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 2}
# {'Best PNL': -2638.8219294003093, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 2}
# {'Best PNL': -2842.247084971837, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 2}
# {'Best PNL': -2618.9359653200427, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 2}
# {'Best PNL': -2599.080023670196, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 2}
# {'Best PNL': -1895.3567703042718, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 3}
# {'Best PNL': -1581.1137449196426, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 3}
# {'Best PNL': -1781.7451499325891, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 3}
# {'Best PNL': -1543.156588070734, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 3}
# {'Best PNL': -2079.5639318806793, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 3}
# {'Best PNL': -1759.5556859629512, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 3}
# {'Best PNL': -2121.7446097442075, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 3}
# {'Best PNL': -1992.449912766049, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 3}
# {'Best PNL': -2268.372762496132, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 3}
# {'Best PNL': -2257.3510357039318, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 3}
# {'Best PNL': -2184.1752461842143, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 3}
# {'Best PNL': -1990.4536596843175, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 3}
# {'Best PNL': -2143.1308132989066, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 3}
# {'Best PNL': -2018.6253350394127, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 3}
# {'Best PNL': -2152.178917571477, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 3}
# {'Best PNL': -1784.138010801589, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 4}
# {'Best PNL': -1603.2552145412988, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 4}
# {'Best PNL': -1762.7064727783215, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 4}
# {'Best PNL': -1407.2227091108048, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 4}
# {'Best PNL': -1989.1284409386756, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 4}
# {'Best PNL': -1827.5185264451165, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 4}
# {'Best PNL': -1948.9234171594894, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 4}
# {'Best PNL': -2001.4096248149872, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 4}
# {'Best PNL': -2025.5397454738613, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 4}
# {'Best PNL': -2233.314385877338, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 4}
# {'Best PNL': -2090.021124431065, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 4}
# {'Best PNL': -1938.8362843104776, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 4}
# {'Best PNL': -2162.9001791136616, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 4}
# {'Best PNL': -1981.347338063377, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 4}
# {'Best PNL': -2161.5820949963177, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 4}
# {'Best PNL': -1180.8324328013832, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 5}
# {'Best PNL': -1068.0066619873055, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 5}
# {'Best PNL': -1225.3858857836046, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 5}
# {'Best PNL': -884.5034412928999, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 5}
# {'Best PNL': -1159.8807149205893, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 5}
# {'Best PNL': -1052.0400148391723, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 5}
# {'Best PNL': -1418.4871330124997, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 5}
# {'Best PNL': -1374.7902607509068, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 5}
# {'Best PNL': -1457.7730778966634, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 5}
# {'Best PNL': -1497.0804704393663, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 5}
# {'Best PNL': -1258.8060584204538, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 5}
# {'Best PNL': -1199.3932200976783, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 5}
# {'Best PNL': -1252.406959152222, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 5}
# {'Best PNL': -1362.3017518452243, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 5}
# {'Best PNL': -1384.486032295227, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 5}
# {'Best PNL': -395.9121940204078, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 6}
# {'Best PNL': -239.76686669758408, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 6}
# {'Best PNL': -395.9121940204078, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 6}
# {'Best PNL': -152.3281956945151, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 6}
# {'Best PNL': -463.6209078925, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 6}
# {'Best PNL': -232.76138053621585, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 6}
# {'Best PNL': -479.2550228527617, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 6}
# {'Best PNL': -534.0526437623166, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 6}
# {'Best PNL': -543.7825073650909, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 6}
# {'Best PNL': -728.7314672742577, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 6}
# {'Best PNL': -612.8309343474256, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 6}
# {'Best PNL': -555.1899823597503, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 6}
# {'Best PNL': -693.7554512841364, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 6}
# {'Best PNL': -727.3995038713731, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 6}
# {'Best PNL': -705.0315934181216, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 6}
# {'Best PNL': 788.8921641213552, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 7}
# {'Best PNL': 794.8310600825716, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 7}
# {'Best PNL': 788.8921641213552, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 7}
# {'Best PNL': 788.8921641213552, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 7}
# {'Best PNL': 788.8921641213552, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 7}
# {'Best PNL': 779.5004818507601, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 7}
# {'Best PNL': 838.2851759774342, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 7}
# {'Best PNL': 767.7942347254071, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 7}
# {'Best PNL': 688.2383583750043, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 7}
# {'Best PNL': 663.4327661786759, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 7}
# {'Best PNL': 688.8265427861893, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 7}
# {'Best PNL': 842.4139512198311, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 7}
# {'Best PNL': 838.7647329057964, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 7}
# {'Best PNL': 765.4787038530621, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 7}
# {'Best PNL': 741.9105233328681, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 7}
# {'Best PNL': 53.79260366984765, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 8}
# {'Best PNL': 53.79260366984765, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 8}
# {'Best PNL': 53.79260366984765, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 8}
# {'Best PNL': 53.79260366984765, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 8}
# {'Best PNL': 53.79260366984765, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 8}
# {'Best PNL': 59.15519522258202, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 8}
# {'Best PNL': 27.562747887202534, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 8}
# {'Best PNL': 27.51651812962109, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 8}
# {'Best PNL': 27.426918084280715, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 8}
# {'Best PNL': 27.562747887202534, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 8}
# {'Best PNL': 53.23598878043026, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 8}
# {'Best PNL': 56.048236778804096, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 8}
# {'Best PNL': 52.39901846476947, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 8}
# {'Best PNL': 59.94584027699048, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 8}
# {'Best PNL': 52.316290215083434, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 8}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 9}
# {'Best PNL': -230.8754444667272, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 9}
# {'Best PNL': -233.3022654942105, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 9}
# {'Best PNL': -236.23803601946156, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 9}
# {'Best PNL': -216.48550044468476, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 9}
# {'Best PNL': -220.30447104317807, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 9}
# {'Best PNL': -220.30447104317807, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 9}
# {'Best PNL': -217.06454533168255, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 9}
# {'Best PNL': -208.91308005196714, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 9}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 10}
# {'Best PNL': -128.5525206293379, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 10}
# {'Best PNL': -125.29187173843388, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 10}
# {'Best PNL': -125.29187173843388, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 10}
# {'Best PNL': -125.29187173843388, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 10}
# {'Best PNL': -122.05194602693835, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 10}
# {'Best PNL': -116.83625127247407, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 10}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 10, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 11, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 12, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 13, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 14, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 15, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 16, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 17, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 18, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 19, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 20, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 21, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 22, 'Best STD BBand': 11}
# {'Best PNL': -3.8141330446515784, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 23, 'Best STD BBand': 11}
# {'Best PNL': 1.4015617098127073, 'Best Moving Average BBand': 15, 'Best Moving Average RSI': 24, 'Best STD BBand': 11}
# {'Best PNL': -2893.7920793056496, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 2}
# {'Best PNL': -2784.696652514594, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 2}
# {'Best PNL': -3040.0764491013133, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 2}
# {'Best PNL': -2634.404577357428, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 2}
# {'Best PNL': -2956.241969210762, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 2}
# {'Best PNL': -2616.301738268988, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 2}
# {'Best PNL': -2792.4662057808478, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 2}
# {'Best PNL': -2899.2985577855793, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 2}
# {'Best PNL': -3055.6965493134107, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 2}
# {'Best PNL': -3068.2755395753047, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 2}
# {'Best PNL': -3022.691788005829, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 2}
# {'Best PNL': -2764.521460614887, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 2}
# {'Best PNL': -2967.9466161864148, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 2}
# {'Best PNL': -2699.5626434462415, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 2}
# {'Best PNL': -2679.7067017963955, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 2}
# {'Best PNL': -1932.8046907356827, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 3}
# {'Best PNL': -1527.9841669968198, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 3}
# {'Best PNL': -1580.2898905958455, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 3}
# {'Best PNL': -1502.2476706300458, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 3}
# {'Best PNL': -2122.0898865495406, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 3}
# {'Best PNL': -1921.9958700111947, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 3}
# {'Best PNL': -2183.1011418138237, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 3}
# {'Best PNL': -1939.854822049823, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 3}
# {'Best PNL': -2184.7736303806314, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 3}
# {'Best PNL': -2294.660226181576, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 3}
# {'Best PNL': -2181.266965784346, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 3}
# {'Best PNL': -2127.9509095055723, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 3}
# {'Best PNL': -2284.386387443544, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 3}
# {'Best PNL': -2094.0142457144607, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 3}
# {'Best PNL': -2283.4669415746434, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 3}
# {'Best PNL': -2242.7555191925594, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 4}
# {'Best PNL': -2079.0791186264587, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 4}
# {'Best PNL': -2170.280028881346, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 4}
# {'Best PNL': -1838.7410593645916, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 4}
# {'Best PNL': -2177.5416749341157, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 4}
# {'Best PNL': -1973.4091367789686, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 4}
# {'Best PNL': -2201.086975812912, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 4}
# {'Best PNL': -2182.9409577778415, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 4}
# {'Best PNL': -2217.3461059842784, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 4}
# {'Best PNL': -2416.6619203976225, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 4}
# {'Best PNL': -2211.0831256866463, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 4}
# {'Best PNL': -2122.1932823453644, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 4}
# {'Best PNL': -2353.3515670231413, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 4}
# {'Best PNL': -2301.346764183045, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 4}
# {'Best PNL': -2427.8948705809466, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 4}
# {'Best PNL': -1601.7037867954803, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 5}
# {'Best PNL': -1488.878015981402, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 5}
# {'Best PNL': -1646.257239777702, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 5}
# {'Best PNL': -1311.982946968079, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 5}
# {'Best PNL': -1517.0553614888881, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 5}
# {'Best PNL': -1408.0835758754192, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 5}
# {'Best PNL': -1699.0727333205095, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 5}
# {'Best PNL': -1768.3774519784115, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 5}
# {'Best PNL': -1717.5142460823058, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 5}
# {'Best PNL': -1889.5411663872858, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 5}
# {'Best PNL': -1638.8595914568218, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 5}
# {'Best PNL': -1478.1149459702629, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 5}
# {'Best PNL': -1520.9959614617492, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 5}
# {'Best PNL': -1638.4175458090651, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 5}
# {'Best PNL': -1657.7023215157649, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 5}
# {'Best PNL': -274.07209627968984, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 6}
# {'Best PNL': -195.69590958186598, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 6}
# {'Best PNL': -274.07209627968984, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 6}
# {'Best PNL': -30.488097953796895, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 6}
# {'Best PNL': -274.07209627968984, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 6}
# {'Best PNL': -269.1437601089483, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 6}
# {'Best PNL': -407.8541087286817, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 6}
# {'Best PNL': -539.1686211041045, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 6}
# {'Best PNL': -545.185572283609, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 6}
# {'Best PNL': -697.9962934494023, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 6}
# {'Best PNL': -516.6740503174922, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 6}
# {'Best PNL': -433.4727216720587, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 6}
# {'Best PNL': -509.92466825757754, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 6}
# {'Best PNL': -540.6334351403375, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 6}
# {'Best PNL': -581.6678080695019, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 6}
# {'Best PNL': 551.2012719018117, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 7}
# {'Best PNL': 557.1401678630282, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 7}
# {'Best PNL': 551.2012719018117, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 7}
# {'Best PNL': 551.2012719018117, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 7}
# {'Best PNL': 551.2012719018117, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 7}
# {'Best PNL': 556.563863454546, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 7}
# {'Best PNL': 524.9714161191665, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 7}
# {'Best PNL': 533.5940545354568, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 7}
# {'Best PNL': 450.5474661554607, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 7}
# {'Best PNL': 425.7418739591324, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 7}
# {'Best PNL': 451.13565056664584, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 7}
# {'Best PNL': 604.7230590002875, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 7}
# {'Best PNL': 601.073840686253, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 7}
# {'Best PNL': 527.7878116335186, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 7}
# {'Best PNL': 504.2196311133247, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 7}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 8}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 8}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 8}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 8}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 8}
# {'Best PNL': 190.92362397057656, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 8}
# {'Best PNL': 161.38801475252413, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 8}
# {'Best PNL': 157.88021493639252, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 8}
# {'Best PNL': 161.25218494960225, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 8}
# {'Best PNL': 161.38801475252413, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 8}
# {'Best PNL': 182.2472376142228, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 8}
# {'Best PNL': 192.59442039217254, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 8}
# {'Best PNL': 188.94520207813798, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 8}
# {'Best PNL': 196.49202389035895, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 8}
# {'Best PNL': 125.12849740982043, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 8}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 9}
# {'Best PNL': -111.24636825834006, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 9}
# {'Best PNL': -114.18213878359114, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 9}
# {'Best PNL': -94.42960320881434, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 9}
# {'Best PNL': -98.24857380730771, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 9}
# {'Best PNL': -98.24857380730771, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 9}
# {'Best PNL': -95.00864809581213, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 9}
# {'Best PNL': -86.85718281609678, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 9}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 10}
# {'Best PNL': 53.101081248692054, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 10}
# {'Best PNL': 60.180700738089385, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 10}
# {'Best PNL': 56.36173013959608, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 10}
# {'Best PNL': 56.36173013959608, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 10}
# {'Best PNL': 59.60165585109161, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 10}
# {'Best PNL': 64.81735060555589, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 10}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 11}
# {'Best PNL': 0.21013159070695941, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 11}
# {'Best PNL': 5.425826345171245, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 11}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 10, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 11, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 12, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 13, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 14, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 15, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 16, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 17, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 18, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 19, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 20, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 21, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 22, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 23, 'Best STD BBand': 12}
# {'Best PNL': 0.0, 'Best Moving Average BBand': 16, 'Best Moving Average RSI': 24, 'Best STD BBand': 12}
# {'Best PNL': -3313.654133292609, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 2}
# {'Best PNL': -3002.2814438411174, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 2}
# {'Best PNL': -3313.0989028521954, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 2}
# {'Best PNL': -2851.8658790315912, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 2}
# {'Best PNL': -3216.053119386946, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 2}
# {'Best PNL': -2938.752244200026, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 2}
# {'Best PNL': -3062.441201196399, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 2}
# {'Best PNL': -3164.2639834540246, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 2}
# {'Best PNL': -3302.293672282357, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 2}
# {'Best PNL': -3308.8441669736612, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 2}
# {'Best PNL': -3270.08489442553, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 2}
# {'Best PNL': -3082.20057428905, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 2}
# {'Best PNL': -3216.1723432813383, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 2}
# {'Best PNL': -2952.680942944119, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 2}
# {'Best PNL': -2876.73210804803, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 2}
# {'Best PNL': -1811.246875531335, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 3}
# {'Best PNL': -1360.6450366156444, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 3}
# {'Best PNL': -1600.724951267245, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 3}
# {'Best PNL': -1471.4775688171394, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 3}
# {'Best PNL': -2039.9717061587746, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 3}
# {'Best PNL': -1802.6123690877653, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 3}
# {'Best PNL': -2003.2457327570241, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 3}
# {'Best PNL': -1821.5815607207157, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 3}
# {'Best PNL': -2052.1408031531746, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 3}
# {'Best PNL': -2265.2358148302355, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 3}
# {'Best PNL': -2088.587756756375, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 3}
# {'Best PNL': -2090.105170018333, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 3}
# {'Best PNL': -2246.5406479563035, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 3}
# {'Best PNL': -2056.1685062272227, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 3}
# {'Best PNL': -2307.742217976707, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 3}
# {'Best PNL': -1926.1873620237627, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 4}
# {'Best PNL': -1689.619735724586, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 4}
# {'Best PNL': -1855.546584830966, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 4}
# {'Best PNL': -1607.8959185804642, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 4}
# {'Best PNL': -2013.7790197031838, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 4}
# {'Best PNL': -1946.1281037534986, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 4}
# {'Best PNL': -2391.8651189872216, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 4}
# {'Best PNL': -2256.9819103990285, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 4}
# {'Best PNL': -2276.7649301392694, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 4}
# {'Best PNL': -2434.2399852752687, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 4}
# {'Best PNL': -2278.18773998533, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 4}
# {'Best PNL': -2049.8869724137458, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 4}
# {'Best PNL': -2328.4776746341176, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 4}
# {'Best PNL': -2276.47287179402, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 4}
# {'Best PNL': -2348.0322993142277, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 4}
# {'Best PNL': -1234.3481835910259, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 5}
# {'Best PNL': -1127.114410877229, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 5}
# {'Best PNL': -1284.493634673528, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 5}
# {'Best PNL': -1023.85037935802, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 5}
# {'Best PNL': -1292.3851977212094, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 5}
# {'Best PNL': -1267.8324138505125, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 5}
# {'Best PNL': -1520.8328211511887, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 5}
# {'Best PNL': -1572.4695239748282, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 5}
# {'Best PNL': -1523.5104805128926, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 5}
# {'Best PNL': -1707.2517595836102, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 5}
# {'Best PNL': -1398.2965410641264, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 5}
# {'Best PNL': -1305.2158634458278, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 5}
# {'Best PNL': -1287.833871473586, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 5}
# {'Best PNL': -1399.1791664668494, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 5}
# {'Best PNL': -1468.0469981738506, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 5}
# {'Best PNL': -444.67363399778117, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 6}
# {'Best PNL': -366.29744729995775, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 6}
# {'Best PNL': -444.67363399778117, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 6}
# {'Best PNL': -201.08963567188871, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 6}
# {'Best PNL': -444.67363399778117, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 6}
# {'Best PNL': -439.31104244504706, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 6}
# {'Best PNL': -548.2542069435125, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 6}
# {'Best PNL': -602.6263360704696, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 6}
# {'Best PNL': -611.9958964075363, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 6}
# {'Best PNL': -666.667486190796, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 6}
# {'Best PNL': -488.70924576350615, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 6}
# {'Best PNL': -397.11660503659925, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 6}
# {'Best PNL': -480.1133660725185, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 6}
# {'Best PNL': -507.18388832637226, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 6}
# {'Best PNL': -547.3222064835686, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 6}
# {'Best PNL': 13.823103564125958, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 7}
# {'Best PNL': 19.761999525342503, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 11, 'Best STD BBand': 7}
# {'Best PNL': 13.823103564125958, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 12, 'Best STD BBand': 7}
# {'Best PNL': 125.94959630966164, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 13, 'Best STD BBand': 7}
# {'Best PNL': 13.823103564125958, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 14, 'Best STD BBand': 7}
# {'Best PNL': 19.18569511686033, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 15, 'Best STD BBand': 7}
# {'Best PNL': 13.823103564125958, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 16, 'Best STD BBand': 7}
# {'Best PNL': 22.44574198041621, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 17, 'Best STD BBand': 7}
# {'Best PNL': -60.60084639957988, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 18, 'Best STD BBand': 7}
# {'Best PNL': -60.465016596658046, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 19, 'Best STD BBand': 7}
# {'Best PNL': -27.13402249472496, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 20, 'Best STD BBand': 7}
# {'Best PNL': 122.085234083448, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 21, 'Best STD BBand': 7}
# {'Best PNL': 122.29979053224818, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 22, 'Best STD BBand': 7}
# {'Best PNL': 187.21109685897812, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 23, 'Best STD BBand': 7}
# {'Best PNL': 116.34341900689239, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 24, 'Best STD BBand': 7}
# {'Best PNL': 115.75327168873369, 'Best Moving Average BBand': 17, 'Best Moving Average RSI': 10, 'Best STD BBand': 8}
# ...
# {'Best PNL': -711.2706737382073, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 6}
# {'Best PNL': -792.7731487137935, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 6}
# {'Best PNL': -792.9069399561205, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 6}
# {'Best PNL': -801.6478152002612, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 6}
# {'Best PNL': -790.4795081411091, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 6}
# {'Best PNL': -640.0328785896306, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 6}
# {'Best PNL': -608.5044362476896, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 6}
# {'Best PNL': -619.2454569407876, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 6}
# {'Best PNL': -727.4430772917615, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 6}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 7}
# {'Best PNL': 262.7278438840591, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 7}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 7}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 7}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 7}
# {'Best PNL': 195.65314470018626, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 7}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 7}
# {'Best PNL': 193.22632367270296, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 7}
# {'Best PNL': 193.13672362736256, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 7}
# {'Best PNL': 190.29055314745185, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 7}
# {'Best PNL': 197.63988960811037, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 7}
# {'Best PNL': 340.72133666447206, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 7}
# {'Best PNL': 337.81476684297814, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 7}
# {'Best PNL': 402.726073169708, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 7}
# {'Best PNL': 376.441610908508, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 7}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 8}
# {'Best PNL': 533.3962337357656, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 8}
# {'Best PNL': 528.0336421830312, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 8}
# {'Best PNL': 663.6389714241026, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 8}
# {'Best PNL': 663.6389714241026, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 8}
# {'Best PNL': 809.3831286157879, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 8}
# {'Best PNL': 668.7179893902369, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 8}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 9}
# {'Best PNL': 249.03013980048036, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 9}
# {'Best PNL': 252.27006551197582, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 9}
# {'Best PNL': 177.97076850618618, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 9}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 10}
# {'Best PNL': 60.81770933696191, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 10}
# {'Best PNL': 64.05763504845748, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 10}
# {'Best PNL': 69.27332980292181, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 10}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 11}
# {'Best PNL': 282.57253702708647, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 11}
# {'Best PNL': 287.78823178155073, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 11}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 10, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 11, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 12, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 13, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 14, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 15, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 16, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 17, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 18, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 19, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 20, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 21, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 22, 'Best STD BBand': 12}
# {'Best PNL': 63.16292946679249, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 23, 'Best STD BBand': 12}
# {'Best PNL': 68.37862422125679, 'Best Moving Average BBand': 21, 'Best Moving Average RSI': 24, 'Best STD BBand': 12}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1104         try:
# -> 1105             self._set_with_engine(key, value)
#    1106         except KeyError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1174     def _set_with_engine(self, key, value) -> None:
# -> 1175         loc = self.index.get_loc(key)
#    1176
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     732             # unrecognized type
# --> 733             raise KeyError(key)
#     734
#
# KeyError: 1786
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5913         try:
# -> 5914             object.__getattribute__(self, name)
#    5915             return object.__setattr__(self, name, value)
#
# AttributeError: 'Series' object has no attribute '_cacher'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-afeb30e6113f> in <cell line: 1>()
# ----> 1 best_param_bris(data)
#
# <ipython-input-55-5ac6a8aaed60> in best_param_bris(df)
#      14                 data.dropna(inplace=True)
#      15                 data = strategy(data)
# ---> 16                 data = tpsl(data)
#      17                 data = target(data)
#      18
#
# <ipython-input-8-22866ea476f9> in tpsl(data)
#       8         else:
#       9             data['Take Profit'][i] = np.nan
# ---> 10             data['Stop Loss'][i] = np.nan
#      11
#      12     return data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1122                 # can't use _mgr.setitem_inplace yet bc could have *both*
#    1123                 #  KeyError and then ValueError, xref GH#45070
# -> 1124                 self._set_values(key, value)
#    1125             else:
#    1126                 # GH#12862 adding a new key to the Series
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _set_values(self, key, value)
#    1214
#    1215         self._mgr = self._mgr.setitem(indexer=key, value=value)
# -> 1216         self._maybe_update_cacher()
#    1217
#    1218     def _set_value(self, label, value, takeable: bool = False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _maybe_update_cacher(self, clear, verify_is_copy, inplace)
#    1315                 # to ensure column still in dataframe
#    1316                 # otherwise, either self or ref has swapped in new arrays
# -> 1317                 ref._maybe_cache_changed(cacher[0], self, inplace=inplace)
#    1318             else:
#    1319                 # GH#33675 we have swapped in a new array, so parent
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _maybe_cache_changed(self, item, value, inplace)
#    4300         arraylike = value._values
#    4301
# -> 4302         old = self._ixs(loc, axis=1)
#    4303         if old._values is value._values and inplace:
#    4304             # GH#46149 avoid making unnecessary copies/block-splitting
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3732
#    3733             # this is a cached value, mark it so
# -> 3734             result._set_as_cached(label, self)
#    3735             return result
#    3736
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _set_as_cached(self, item, cacher)
#    1270         cacher.
#    1271         """
# -> 1272         self._cacher = (item, weakref.ref(cacher))
#    1273
#    1274     def _clear_item_cache(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5912
#    5913         try:
# -> 5914             object.__getattribute__(self, name)
#    5915             return object.__setattr__(self, name, value)
#    5916         except AttributeError:
#
# KeyboardInterrupt:

# %% [markdown]
# ## DATASET

# %%
data=yf.download('MSFT',period='10y',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data=bbands(data,15,7)
data=RSI(data,21)
data=average_true_range(data)
data.dropna(inplace=True)
data=strategy(data)

# %%
data.Signal.value_counts()
# Out:
# Signal
# Null    2387
# Buy      110
# Name: count, dtype: int64

# %%
data=tpsl(data)
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-07-18   44.650002   44.840000   44.250000   44.689999   38.110680
# 2014-07-21   44.560001   45.160000   44.220001   44.840000   38.238586
# 2014-07-22   45.000000   45.150002   44.590000   44.830002   38.230076
# 2014-07-23   45.450001   45.450001   44.619999   44.869999   38.264179
# 2014-07-24   44.930000   45.000000   44.320000   44.400002   37.863388
# ...                ...         ...         ...         ...         ...
# 2024-06-12  435.320007  443.399994  433.250000  441.059998  441.059998
# 2024-06-13  440.850006  443.390015  439.369995  441.579987  441.579987
# 2024-06-14  438.279999  443.140015  436.720001  442.570007  442.570007
# 2024-06-17  442.589996  450.940002  440.720001  448.369995  448.369995
# 2024-06-18  449.709991  450.140015  444.890015  446.339996  446.339996
#
#               Volume   UpperBand   LowerBand       Trend         RSI  \
# Date
# 2014-07-18  43407500   44.297332   40.586667   42.442000  147.798872
# 2014-07-21  37604400   44.758091   40.471242   42.614666  145.645749
# 2014-07-22  43095800   45.134599   40.512067   42.823333  148.571487
# 2014-07-23  52362900   45.458123   40.588544   43.023333  153.125141
# 2014-07-24  30725300   45.634503   40.745497   43.190000  166.414993
# ...              ...         ...         ...         ...         ...
# 2024-06-12  22366200  438.990405  411.749597  425.370001  188.953841
# 2024-06-13  15960600  441.450388  410.764281  426.107334  197.202188
# 2024-06-14  13582000  444.203622  410.087048  427.145335  224.781688
# 2024-06-17  20790000  447.922183  408.796485  428.359334  181.190564
# 2024-06-18  17085700  450.613279  408.241389  429.427334  189.858309
#
#             OverBought  OverSold       ATR Signal  Take Profit  Stop Loss
# Date
# 2014-07-18          70        30  0.665715   Null          NaN        NaN
# 2014-07-21          70        30  0.696429   Null          NaN        NaN
# 2014-07-22          70        30  0.703572   Null          NaN        NaN
# 2014-07-23          70        30  0.736429   Null          NaN        NaN
# 2014-07-24          70        30  0.754286   Null          NaN        NaN
# ...                ...       ...       ...    ...          ...        ...
# 2024-06-12          70        30  7.040710   Null          NaN        NaN
# 2024-06-13          70        30  6.743570   Null          NaN        NaN
# 2024-06-14          70        30  6.727142   Null          NaN        NaN
# 2024-06-17          70        30  7.155714   Null          NaN        NaN
# 2024-06-18          70        30  7.155714   Null          NaN        NaN
#
# [2497 rows x 16 columns]

# %%
data=target(data)

# %%
buy=[]
for i in range(len(data)):
    if data.Signal[i]=='Buy':
        buy.append(data.Close[i])
    else:
        buy.append(np.nan)

df=data.copy()
df['Buy']=buy

# %% [markdown]
# ## Plotting Graph of Buy SIGNAL

# %%
# Plot the close price , bollinger bands and trading signals(buy & sell signals)
fig,ax=plt.subplots(figsize=(16,8))
plt.title('Bollinger Band, RSI and ATR Trading Strategy')
plt.grid(True)
plt.ylabel('Price in USD')
plt.xlabel('Dates')
ax.plot(data['Close'],label='Close Price',alpha=0.25,color='blue')
ax.plot(data['UpperBand'],label='Upper Band',alpha=0.25,color='yellow')
ax.plot(data['LowerBand'],label='Lower Band',alpha=0.25,color='purple')
ax.fill_between(data.index,data['UpperBand'],data['LowerBand'],color='grey')
ax.scatter(df.index,df['Buy'],label='Buy',alpha=1,marker='^',color='green')
plt.legend()
plt.show()

# %% [markdown]
# ## This is a dataframe in which only buy with their take profit and stop loss
# ......

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-07-18   44.650002   44.840000   44.250000   44.689999   38.110680
# 2014-07-21   44.560001   45.160000   44.220001   44.840000   38.238586
# 2014-07-22   45.000000   45.150002   44.590000   44.830002   38.230076
# 2014-07-23   45.450001   45.450001   44.619999   44.869999   38.264179
# 2014-07-24   44.930000   45.000000   44.320000   44.400002   37.863388
# ...                ...         ...         ...         ...         ...
# 2024-06-12  435.320007  443.399994  433.250000  441.059998  441.059998
# 2024-06-13  440.850006  443.390015  439.369995  441.579987  441.579987
# 2024-06-14  438.279999  443.140015  436.720001  442.570007  442.570007
# 2024-06-17  442.589996  450.940002  440.720001  448.369995  448.369995
# 2024-06-18  449.709991  450.140015  444.890015  446.339996  446.339996
#
#               Volume   UpperBand   LowerBand       Trend         RSI  \
# Date
# 2014-07-18  43407500   44.297332   40.586667   42.442000  147.798872
# 2014-07-21  37604400   44.758091   40.471242   42.614666  145.645749
# 2014-07-22  43095800   45.134599   40.512067   42.823333  148.571487
# 2014-07-23  52362900   45.458123   40.588544   43.023333  153.125141
# 2014-07-24  30725300   45.634503   40.745497   43.190000  166.414993
# ...              ...         ...         ...         ...         ...
# 2024-06-12  22366200  438.990405  411.749597  425.370001  188.953841
# 2024-06-13  15960600  441.450388  410.764281  426.107334  197.202188
# 2024-06-14  13582000  444.203622  410.087048  427.145335  224.781688
# 2024-06-17  20790000  447.922183  408.796485  428.359334  181.190564
# 2024-06-18  17085700  450.613279  408.241389  429.427334  189.858309
#
#             OverBought  OverSold       ATR Signal  Take Profit  Stop Loss  \
# Date
# 2014-07-18          70        30  0.665715   Null          NaN        NaN
# 2014-07-21          70        30  0.696429   Null          NaN        NaN
# 2014-07-22          70        30  0.703572   Null          NaN        NaN
# 2014-07-23          70        30  0.736429   Null          NaN        NaN
# 2014-07-24          70        30  0.754286   Null          NaN        NaN
# ...                ...       ...       ...    ...          ...        ...
# 2024-06-12          70        30  7.040710   Null          NaN        NaN
# 2024-06-13          70        30  6.743570   Null          NaN        NaN
# 2024-06-14          70        30  6.727142   Null          NaN        NaN
# 2024-06-17          70        30  7.155714   Null          NaN        NaN
# 2024-06-18          70        30  7.155714   Null          NaN        NaN
#
#             Target  Buy
# Date
# 2014-07-18     NaN  NaN
# 2014-07-21     NaN  NaN
# 2014-07-22     NaN  NaN
# 2014-07-23     NaN  NaN
# 2014-07-24     NaN  NaN
# ...            ...  ...
# 2024-06-12     NaN  NaN
# 2024-06-13     NaN  NaN
# 2024-06-14     NaN  NaN
# 2024-06-17     NaN  NaN
# 2024-06-18     NaN  NaN
#
# [2497 rows x 18 columns]

# %%
df['PNL']=data['Target']-data['Close']

# %%
df['PNL'].sum()
# Out:
# 4605.325285230364

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'UpperBand',
#        'LowerBand', 'Trend', 'RSI', 'OverBought', 'OverSold', 'ATR', 'Signal',
#        'Take Profit', 'Stop Loss', 'Target', 'Buy', 'PNL'],
#       dtype='object')

# %% [markdown]
# ## Doing Backtesting Now,

# %%
df2=data.copy()

# %%
import pandas as pd
from tabulate import tabulate

class Backtest:
    def __init__(self):
        self.columns = ['Equity Name', 'Trade', 'Entry Time', 'Entry Price', 'Exit Time', 'Exit Price', 'Quantity', 'Position Size', 'PNL', '% PNL']
        self.backtesting = pd.DataFrame(columns=self.columns)
        self.stop_loss = None
        self.take_profit = None

    def set_stop_loss(self, price):
        self.stop_loss = price

    def remove_stop_loss(self):
        self.stop_loss = None

    def set_take_profit(self, price):
        self.take_profit = price

    def remove_take_profit(self):
        self.take_profit = None

    def buy(self, equity_name, entry_time, entry_price, qty):
        self.trade_board = dict(zip(self.columns, [None] * len(self.columns)))
        self.trade_board['Trade'] = 'Open'
        self.trade_board['Quantity'] = qty
        self.trade_board['Position Size'] = round(self.trade_board['Quantity'] * entry_price, 3)
        self.trade_board['Equity Name'] = equity_name
        self.trade_board['Entry Time'] = entry_time
        self.trade_board['Entry Price'] = round(entry_price, 2)

    def sell(self, exit_time, exit_price, exit_type, charge=0):
        exit_timestamp = data.index[exit_time]
        self.trade_board['Holding Days'] = (exit_timestamp - self.trade_board['Entry Time']).days
        self.trade_board['Exit Time'] = exit_time
        self.trade_board['Exit Price'] = round(exit_price, 2)
        self.trade_board['Trade'] = 'Closed'
        self.trade_board['Exit Type'] = exit_type
        self.trade_board['PNL'] = round((self.trade_board['Exit Price'] - self.trade_board['Entry Price']) * self.trade_board['Quantity'], 2)
        self.trade_board['% PNL'] = round((self.trade_board['PNL'] / self.trade_board['Position Size']) * 100, 3)
        new_row = pd.DataFrame([self.trade_board])
        self.backtesting = pd.concat([self.backtesting, new_row], ignore_index=True)

    def stats(self):
        df = self.backtesting
        df2 = df.copy()
        parameters = ['Total Trade Scripts', 'Total Trade', 'PNL', 'Winners', 'Losers', 'Win Ratio', 'Total Profit', 'Total Loss', 'Max Loss Trade', 'Max Profitable Trade', 'Average Loss per Trade', 'Average Profit per Trade', 'Average PNL Per Trade', 'Risk Reward']
        total_traded_scripts = len(df['Equity Name'].unique())
        total_trade = len(df.index)
        pnl = df.PNL.sum()
        winners = len(df[df.PNL > 0])
        losers = len(df[df.PNL <= 0])
        win_ratio = str(round((winners / total_trade) * 100, 2)) + '%'
        total_profit = round(df[df.PNL > 0].PNL.sum(), 2)
        total_loss = round(df[df.PNL <= 0].PNL.sum(), 2)
        max_loss_trade = round(df[df.PNL <= 0].PNL.min(), 3)
        max_profit_trade = round(df[df.PNL >= 0].PNL.max(), 3)
        average_loss_per_trade = round(total_loss / losers, 2)
        average_profit_per_trade = round(total_profit / winners, 2)
        average_pnl_per_trade = round(pnl / total_trade, 2)
        risk_reward = f'1:{-1 * round(average_profit_per_trade / average_loss_per_trade, 2)}'
        data_points = [total_traded_scripts, total_trade, pnl, winners, losers, win_ratio, total_profit, total_loss, max_loss_trade, max_profit_trade, average_loss_per_trade, average_profit_per_trade, average_pnl_per_trade, risk_reward]
        data = list(zip(parameters, data_points))
        x = tabulate(data, ['Parameters', 'Values'], tablefmt='psql')
        return x

# %%
def backtest_strategy(data):
    bt = Backtest()
    capital=100000
    for i in range(len(data)):
        if data.Signal[i] == 'Buy':
            qty = capital // data.Open[i]
            bt.buy(equity_name='MSFT',entry_time=data.index[i], entry_price=data.Close[i],qty=qty)
            bt.set_take_profit(data.Close[i] + data['Take Profit'][i])
            bt.set_stop_loss(data.Close[i] - data['Stop Loss'][i])
            for j in range(i + 1, len(data)):
                if data.Close[j] >= bt.take_profit:
                    bt.sell(exit_time=j, exit_price=bt.take_profit,exit_type='Take Profit')
                    break
                elif data.Close[j] <= bt.stop_loss:
                    bt.sell(exit_time=j, exit_price=bt.stop_loss, exit_type='Stop Loss')
                    break

            if bt.trade_board['Trade'] == 'Open':  # If still open by end of data
                bt.sell(exit_time=len(data)-1, exit_price=data.Close.iloc[-1], exit_type='End of Data')

    return bt.backtesting,bt.stats()

# %%
data1,x=backtest_strategy(data)

# %%
data1
# Out:
#     Equity Name   Trade Entry Time  Entry Price Exit Time  Exit Price  \
# 0          MSFT  Closed 2014-10-10        44.03       515       56.86
# 1          MSFT  Closed 2014-10-13        43.65       516       57.08
# 2          MSFT  Closed 2014-10-14        43.73       516       57.21
# 3          MSFT  Closed 2014-10-15        43.22       515       56.95
# 4          MSFT  Closed 2014-10-16        42.74       365       56.47
# ..          ...     ...        ...          ...       ...         ...
# 105        MSFT  Closed 2024-04-16       414.58      2496      446.34
# 106        MSFT  Closed 2024-04-17       411.84      2496      446.34
# 107        MSFT  Closed 2024-04-18       404.27      2496      446.34
# 108        MSFT  Closed 2024-04-19       399.12      2496      446.34
# 109        MSFT  Closed 2024-04-30       389.33      2496      446.34
#
#      Quantity  Position Size       PNL   % PNL  Holding Days    Exit Type
# 0      2192.0      96513.757  28123.36  29.139         663.0  Take Profit
# 1      2282.0      99609.303  30647.26  30.767         661.0  Take Profit
# 2      2279.0      99660.669  30720.92  30.826         660.0  Take Profit
# 3      2325.0     100486.503  31922.25  31.768         658.0  Take Profit
# 4      2351.0     100481.744  32279.23  32.124         439.0  Take Profit
# ..        ...            ...       ...     ...           ...          ...
# 105     241.0      99913.777   7654.16   7.661          63.0  End of Data
# 106     239.0      98429.759   8245.50   8.377          62.0  End of Data
# 107     243.0      98237.607  10223.01  10.406          61.0  End of Data
# 108     247.0      98582.639  11663.34  11.831          60.0  End of Data
# 109     249.0      96943.167  14195.49  14.643          49.0  End of Data
#
# [110 rows x 12 columns]

# %%
data1.to_csv('Summary_of_trade_MSFT.csv')

# %%
def calculate_equity_curve(data):
    equity_curve = [0]  # Initialize with zero equity
    for i in range(1, len(data)):
        equity_curve.append(equity_curve[-1] + data['PNL'][i])  # Calculate equity for each day

    return equity_curve

# Assuming you have a DataFrame named 'data1' with 'PNL' values
equity_curve = calculate_equity_curve(data1)

# %%
plt.plot(equity_curve)

# %%
print(x)
# Out:
# +--------------------------+------------+
# | Parameters               | Values     |
# |--------------------------+------------|
# | Total Trade Scripts      | 1          |
# | Total Trade              | 110        |
# | PNL                      | 3303263.23 |
# | Winners                  | 103        |
# | Losers                   | 7          |
# | Win Ratio                | 93.64%     |
# | Total Profit             | 3453696.87 |
# | Total Loss               | -150433.64 |
# | Max Loss Trade           | -25300.08  |
# | Max Profitable Trade     | 106871.52  |
# | Average Loss per Trade   | -21490.52  |
# | Average Profit per Trade | 33531.04   |
# | Average PNL Per Trade    | 30029.67   |
# | Risk Reward              | 1:1.56     |
# +--------------------------+------------+

# %%
max_drawdown = 0  # Initialize the maximum drawdown to 0
peak = equity_curve[0]  # Initialize the peak value

for i in range(1, len(equity_curve)):
    if equity_curve[i] > peak:
        peak = equity_curve[i]  # Update the peak value if a new high is reached
    else:
        drawdown = (equity_curve[i] - peak) / peak  # Calculate the drawdown
        if drawdown < max_drawdown:
            max_drawdown = drawdown  # Update the maximum drawdown if a greater drawdown is encountered
print(max_drawdown*-100,'%')

# The variable 'max_drawdown' now contains the maximum drawdown as a decimal value
# Out:
# 6.6813591423717735 %

# %%
maximum_drawdown=17.75

# %%
data1['PNL'].sum()
# Out:
# 3303263.23

# %%
equity_starting=100000
total_returns = (data1['PNL'].sum() - equity_starting) / equity_starting
total_returns_percentage = total_returns * 100

sharpe_ratio = total_returns / maximum_drawdown

# %%
print(sharpe_ratio)
# Out:
# 1.8046553408450705
